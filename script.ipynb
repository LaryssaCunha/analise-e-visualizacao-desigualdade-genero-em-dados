# %%
#importando as bibliotecas que serão utilizadas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#visualizando e armazenando o primeiro dataframe
df_std2022 = pd.read_csv('./dados brutos/state-of-data-brazil-2022.csv', sep=',')
df_std2022
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96                39.0
# 1     zzls2oftfn9law393oezzls2ofhvfpzd                32.0
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi                53.0
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl                27.0
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg                46.0
# ...                                ...                 ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp                26.0
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp                30.0
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3                29.0
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de                 NaN
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7                24.0
#
#      ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         30-34           Masculino
# 2                         50-54           Masculino
# ...

# %%
df_std2022.columns
# Out:
# Index(['('P0', 'id')', '('P1_a ', 'Idade')', '('P1_a_1 ', 'Faixa idade')',
#        '('P1_b ', 'Genero')', '('P1_c ', 'Cor/raca/etnia')',
#        '('P1_d ', 'PCD')', '('P1_e ', 'experiencia_profissional_prejudicada')',
#        '('P1_f ', 'aspectos_prejudicados')', '('P1_g ', 'vive_no_brasil')',
#        '('P1_i ', 'Estado onde mora')',
#        ...
#        '('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')',
#        '('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')',
#        '('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')',
#        '('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')',
# ...

# %%
#selecionando as colunas que serão utilizadas do dataframe
df_std2022 = df_std2022.loc[:, ["('P0', 'id')",
"('P1_a ', 'Idade')",
"('P1_b ', 'Genero')",
"('P1_c ', 'Cor/raca/etnia')",
"('P1_d ', 'PCD')",
"('P1_e ', 'experiencia_profissional_prejudicada')",
"('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
"('P1_l ', 'Nivel de Ensino')",
"('P1_m ', 'Área de Formação')",
"('P2_a ', 'Qual sua situação atual de trabalho?')",
"('P2_g ', 'Nivel')",
"('P2_h ', 'Faixa salarial')",
"('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
"('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
"('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
"('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
"('P2_p ', 'Atualmente qual a sua forma de trabalho?')"
]]

# %%
#visualização dos tipos de colunas
df_std2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 17 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   ('P0', 'id')                                                                                                    4271 non-null   object
#  1   ('P1_a ', 'Idade')                                                                                              4197 non-null   float64
#  2   ('P1_b ', 'Genero')                                                                                             4262 non-null   object
#  3   ('P1_c ', 'Cor/raca/etnia')                                                                                     4271 non-null   object
# ...

# %%
#visualização de quantos valores nulos tem por coluna
df_std2022.isnull().sum()
# Out:
# ('P0', 'id')                                                                                                         0
# ('P1_a ', 'Idade')                                                                                                  74
# ('P1_b ', 'Genero')                                                                                                  9
# ('P1_c ', 'Cor/raca/etnia')                                                                                          0
# ('P1_d ', 'PCD')                                                                                                     0
# ('P1_e ', 'experiencia_profissional_prejudicada')                                                                 2081
# ('P2_l_2 ', 'Salário atual não corresponde ao mercado')                                                           3311
# ('P1_l ', 'Nivel de Ensino')                                                                                         0
# ...

# %%
#deletando as colunas que há um grande número de valores nulos e armazenando a atualização no df
deletar_colunas_2022 = ["('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
    "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
    "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')"
]

df_std2022 = df_std2022.drop(deletar_colunas_2022, axis=1)
df_std2022
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96                39.0
# 1     zzls2oftfn9law393oezzls2ofhvfpzd                32.0
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi                53.0
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl                27.0
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg                46.0
# ...                                ...                 ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp                26.0
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp                30.0
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3                29.0
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de                 NaN
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7                24.0
#
#      ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia') ('P1_d ', 'PCD')  \
# 0              Masculino                       Parda              Não
# 1              Masculino                       Parda              Não
# ...

# %%
#Renomeando as colunas
df_std2022 = df_std2022.rename(columns = {
"('P0', 'id')"  : "id",
"('P1_a ', 'Idade')" : "idade",
"('P1_b ', 'Genero')" : "genero",
"('P1_c ', 'Cor/raca/etnia')" : "raca",
"('P1_d ', 'PCD')" : "pcd",
"('P1_e ', 'experiencia_profissional_prejudicada')" : "experiencia profissional prejudicada", 
"('P2_l_2 ', 'Salário atual não corresponde ao mercado')" : "salario nao corresponde ao mercado",
"('P1_l ', 'Nivel de Ensino')" : "nivel de ensino",
"('P1_m ', 'Área de Formação')" : "area de formacao",
"('P2_a ', 'Qual sua situação atual de trabalho?')" : "situacao atual profissional",
"('P2_g ', 'Nivel')" : "nivel",
"('P2_h ', 'Faixa salarial')" : "faixa salarial",
"('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')" : "participacao em entrevistas nos ultimos 6 meses",
"('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')" : "tempo de espera em oportunidade no mercado",
"('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')" : "busca por emprego",
"('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')" : "principais criterios para trabalhar em um lugar",
"('P2_p ', 'Atualmente qual a sua forma de trabalho?')" : "atual forma de trabalho"
})

df_std2022.head(5)
# Out:
#                                  id  idade     genero    raca  pcd  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0  Masculino   Parda  Não
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0  Masculino   Parda  Não
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0  Masculino  Branca  Não
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0  Masculino  Branca  Não
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0   Feminino  Branca  Não
#
#                 experiencia profissional prejudicada        nivel de ensino  \
# 0  Não acredito que minha experiência profissiona...          Pós-graduação
# 1  Sim, acredito que a minha a experiência profis...  Graduação/Bacharelado
# 2                                                NaN          Pós-graduação
# 3                                                NaN       Doutorado ou Phd
# 4  Não acredito que minha experiência profissiona...          Pós-graduação
#
#                                     area de formacao  \
# ...

# %%
df_std2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               4271 non-null   object
#  1   idade                                            4197 non-null   float64
#  2   genero                                           4262 non-null   object
#  3   raca                                             4271 non-null   object
#  4   pcd                                              4271 non-null   object
#  5   experiencia profissional prejudicada             2190 non-null   object
#  6   nivel de ensino                                  4271 non-null   object
#  7   area de formacao                                 4149 non-null   object
#  8   situacao atual profissional                      4271 non-null   object
# ...

# %%
df_std2022.to_csv('std2022.csv', index=False)

# %% [markdown]
# * Tratamento do segundo dataset 'state-of-data-2023.csv'

# %%
#visualizando e armazenando o segundo dataframe
df_std2023 = pd.read_csv("./dados brutos/state-of-data-brazil-2023.csv",sep=',')
df_std2023
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1     0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3     00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4     00v0az4g792svil00vn6y1kfm9hq8vy9                  34
# ...                                ...                 ...
# 5288  zyg9519671iqrgy93qzyg95183k8ix5f                  34
# 5289  zyppgxzxko25qkgwsbrgpzyppgxzxs81                  32
# 5290  zysl5f50cnz3r0cbe6t2zysrxbzfsrng                  25
# 5291  zyt2656c9e1becxp457zyt26566dsng8                  31
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x                  31
#
#      ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         30-34           Masculino
# 1                         30-34           Masculino
# 2                         35-39            Feminino
# ...

# %%
#selecionando as colunas
std2023_tratado = df_std2023[["('P0', 'id')",
"('P1_a ', 'Idade')",
"('P1_b ', 'Genero')",
"('P1_c ', 'Cor/raca/etnia')",
"('P1_d ', 'PCD')",
"('P1_e ', 'experiencia_profissional_prejudicada')",
"('P1_l ', 'Nivel de Ensino')",
"('P1_m ', 'Área de Formação')",
"('P2_a ', 'Qual sua situação atual de trabalho?')",
"('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
"('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
"('P2_r ', 'Atualmente qual a sua forma de trabalho?')",
"('P2_g ', 'Nivel')",
"('P2_h ', 'Faixa salarial')",
"('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
]]

# %%
#verificando a quantidade de nulos
std2023_tratado.isnull().sum()
# Out:
# ('P0', 'id')                                                                                                         0
# ('P1_a ', 'Idade')                                                                                                   0
# ('P1_b ', 'Genero')                                                                                                  0
# ('P1_c ', 'Cor/raca/etnia')                                                                                          0
# ('P1_d ', 'PCD')                                                                                                     0
# ('P1_e ', 'experiencia_profissional_prejudicada')                                                                 2574
# ('P1_l ', 'Nivel de Ensino')                                                                                         0
# ('P1_m ', 'Área de Formação')                                                                                      113
# ...

# %%
df_std2023 = std2023_tratado.rename(columns = {
"('P0', 'id')"  : "id",
"('P1_a ', 'Idade')" : "idade",
"('P1_b ', 'Genero')" : "genero",
"('P1_c ', 'Cor/raca/etnia')" : "raca",
"('P1_d ', 'PCD')" : "pcd",
"('P1_e ', 'experiencia_profissional_prejudicada')" : "experiencia profissional prejudicada", 
"('P2_l_2 ', 'Salário atual não corresponde ao mercado')" : "salario nao corresponde ao mercado",
"('P1_l ', 'Nivel de Ensino')" : "nivel de ensino",
"('P1_m ', 'Área de Formação')" : "area de formacao",
"('P2_r ', 'Atualmente qual a sua forma de trabalho?')" : "situacao atual profissional",
"('P2_g ', 'Nivel')" : "nivel",
"('P2_h ', 'Faixa salarial')" : "faixa salarial",
"('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')" : "participacao em entrevistas nos ultimos 6 meses",
"('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')" : "tempo de espera em oportunidade no mercado",
})

df_std2023.head(5)
# Out:
#                                  id  idade     genero     raca  pcd  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g     31  Masculino   Branca  Não
# 1  0026aa3fwd78u0026asg7456tfkjg2cs     30  Masculino   Branca  Não
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w     37   Feminino  Amarela  Não
# 3  00urm3jf2cek12w6ygue00urm3jzd17j     22  Masculino    Preta  Não
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9     34  Masculino   Branca  Não
#
#                 experiencia profissional prejudicada         nivel de ensino  \
# 0                                                NaN        Doutorado ou Phd
# 1                                                NaN   Graduação/Bacharelado
# 2  Sim, acredito que a minha a experiência profis...   Graduação/Bacharelado
# 3  Não acredito que minha experiência profissiona...  Estudante de Graduação
# 4                                                NaN        Doutorado ou Phd
#
#                                     area de formacao  \
# ...

# %%
df_std2023.columns
# Out:
# Index(['id', 'idade', 'genero', 'raca', 'pcd',
#        'experiencia profissional prejudicada', 'nivel de ensino',
#        'area de formacao', '('P2_a ', 'Qual sua situação atual de trabalho?')',
#        'participacao em entrevistas nos ultimos 6 meses',
#        '('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')',
#        'situacao atual profissional', 'nivel', 'faixa salarial',
#        'salario nao corresponde ao mercado'],
#       dtype='object')

# %%
#exportando o dataframe tratado para o csv
df_std2023.to_csv('std2023.csv', index=False)

# %% [markdown]
# # **Análise Exploratória:**
# - Buscar uma análise descritiva sobre as experiências das mulheres no mercado de dados ao longo dos anos de 2022 e 2023.
#
#  **Primeira etapa:**
# - Contar quantidade de mulheres e homens nos anos de 2022 e 2023.

# %%
#contando só as coluna de gênero feminino em 2022
quantidade_mulheres_2022 = df_std2022[df_std2022['genero'] == 'Feminino'].count()
quantidade_mulheres_2022 #total de mulheres
# Out:
# id                                                 1056
# idade                                              1047
# genero                                             1056
# raca                                               1056
# pcd                                                1056
# experiencia profissional prejudicada               1054
# nivel de ensino                                    1056
# area de formacao                                   1029
# situacao atual profissional                        1056
# nivel                                               754
# faixa salarial                                      886
# participacao em entrevistas nos ultimos 6 meses     886
# principais criterios para trabalhar em um lugar     886
# atual forma de trabalho                             886
# dtype: int64

# %%
# Contando apenas o número de ocorrências de "Feminino" na coluna "genero"
quantidade_mulheres_2022 = df_std2022[df_std2022['genero'] == 'Feminino'].shape[0]
quantidade_mulheres_2022
# Out:
# 1056

# %%
quantidade_mulheres_2023 = df_std2023[df_std2023['genero'] == 'Feminino'].count()
quantidade_mulheres_2023
# Out:
# id                                                                                                                1293
# idade                                                                                                             1293
# genero                                                                                                            1293
# raca                                                                                                              1293
# pcd                                                                                                               1293
# experiencia profissional prejudicada                                                                              1270
# nivel de ensino                                                                                                   1293
# area de formacao                                                                                                  1273
# ...

# %%
quantidade_mulheres_2023 = df_std2023[df_std2023['genero'] == 'Feminino'].shape[0]
quantidade_mulheres_2023
# Out:
# 1293

# %%
#Contabilizando a diferença absoluta entre o total de mulheres de 2022 e 2023
diferenca_absoluta = quantidade_mulheres_2023 - quantidade_mulheres_2022
diferenca_absoluta
# Out:
# 237

# %%
#Valor do total de mulheres de 2022 ( = 1056) em porcentagem em relação ao total
porcentagem_mulheres_2022 = (quantidade_mulheres_2022 / df_std2022["genero"].count()) * 100
porcentagem_mulheres_2022
# Out:
# 24.777099953073677

# %%
#Valor total de mulheres de 2023 ( = 1293 ) em porcentagem em relação ao total
porcentagem_mulheres_2023 = (quantidade_mulheres_2023 / df_std2023["genero"].count()) * 100
porcentagem_mulheres_2023
# Out:
# 24.42849045909692

# %%
diferenca_percentual = porcentagem_mulheres_2022 - porcentagem_mulheres_2023
f'{diferenca_percentual:.2f}%'
# Out:
# '0.35%'

# %% [markdown]
# ## Análise comparativa em proporção aos homens

# %%
std2022 = pd.read_csv('./dados tratados/std2022.csv')
std2022.head(1)
# Out:
#                                  id  idade     genero   raca  pcd  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0  Masculino  Parda  Não
#
#                 experiencia profissional prejudicada nivel de ensino  \
# 0  Não acredito que minha experiência profissiona...   Pós-graduação
#
#                                     area de formacao  \
# 0  Computação / Engenharia de Software / Sistemas...
#
#   situacao atual profissional   nivel                   faixa salarial  \
# 0            Servidor Público  Júnior  de R$ 8.001/mês a R$ 12.000/mês
#
#      participacao em entrevistas nos ultimos 6 meses  \
# 0  Não participei de entrevistas de emprego/proce...
#
#   principios criterios para trabalhar em um lugar atual forma de trabalho
# 0                                      Benefícios  Modelo 100% presencial

# %%
std2023 = pd.read_csv('./dados tratados/std2023.csv')
std2023.tail(1)
# Out:
#                                     id  idade     genero     raca  pcd  \
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x     31  Masculino  Amarela  Não
#
#                    experiencia profissional prejudicada nivel de ensino  \
# 5292  Não acredito que minha experiência profissiona...   Pós-graduação
#
#                                        area de formacao  \
# 5292  Computação / Engenharia de Software / Sistemas...
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?')  \
# 5292                Desempregado, buscando recolocação
#
#      participacao em entrevistas nos ultimos 6 meses  \
# 5292                                             NaN
#
#      ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 5292                                                NaN
#
#      situacao atual profissional nivel faixa salarial  \
# 5292                         NaN   NaN            NaN
#
#       salario nao corresponde ao mercado
# ...

# %%
#Contando o nº de ocorrências de "Masculino" em 2022
quantidade_homens_2022 = std2022[std2022['genero'] == 'Masculino'].shape[0]
quantidade_homens_2022
# Out:
# 3194

# %%
#Nº de ocorrências de homens em 2023
quantidade_homens_2023 = std2023[std2023['genero'] == 'Masculino'].shape[0]
quantidade_homens_2023
# Out:
# 3975

# %%
#Diferença total absoluta entre a quantidade de homens em 2022 e 2023
diferenca_absoluta_homens = quantidade_homens_2023 - quantidade_homens_2022
diferenca_absoluta_homens
# Out:
# 781

# %%
#Valor total de homens em 2022 (= 3194) em porcentagem em relação ao total
porcentagem_homens_2022 = (quantidade_homens_2022 / std2022["genero"].count()) * 100
porcentagem_homens_2022
# Out:
# 74.94134209291413

# %%
#Valor total de homens em 2023 (= 3975) em porcentagem em relação ao total
porcentagem_homens_2023 = (quantidade_homens_2023 / std2023["genero"].count()) * 100
porcentagem_homens_2023
# Out:
# 75.09918760627244

# %%
#Diferença percentual da entrade de homens em 2022 e 2023
diferenca_percentual_homens = porcentagem_homens_2023 - porcentagem_homens_2022
f'{diferenca_percentual_homens:.2f}%'
# Out:
# '0.16%'

# %% [markdown]
# # **Visualização dos dados.**

# %%
#Comparação absoluta das mulheres entre 2022 e 2023
categorias1 = ["Mulheres em Dados em 2022", "Mulheres em Dados em 2023"]
valores = [quantidade_mulheres_2022, quantidade_mulheres_2023]

#Criando o g´rafico de barras
plt.figure(figsize=(8, 6)) #Ajuste o tamanho da figura
barras = plt.bar(categorias1, valores, color='#FF69B4', edgecolor = 'black')

#Ajustando o eixo Y para mostrar apenas entre 100 e 1500
plt.ylim(1000, 1350)

#Adicionando os rótulos acima das barras
for barra in barras:
    altura = barra.get_height()
    plt.text(
        barra.get_x() + barra.get_width() / 2, altura + 10, #Posição acima da barra
        f'{altura}', #Valor da barra
        ha='center', va='bottom', fontsize=12, color='black', fontweight='bold'            
    )

#Ajustando os rótulos e os títulos
plt.title("Comparação do total de mulheres em dados (2022 vs 2023)", fontsize=14, fontweight='bold')
plt.ylabel("Quantidade", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

#Mostrando o gráfico
plt.tight_layout()
plt.show()

# %%
#Porcentagem comparativa entre mulheres em 2022 e 2023
categorias2 = ["Porcentagem de mulheres em dados em 2022", "Porcentagem de mulheres em dados em 2023"]
valores2 = [porcentagem_mulheres_2022, porcentagem_mulheres_2023]

#Criando o gráfico de barras
plt.figure(figsize=(12, 7)) #Ajusta o tamanho da figura
barras2 = plt.bar(categorias2, valores2, color="#FF69B4", edgecolor='black')

#Ajustando o eixo Y para mostrar apenas entre 23% e 25%
plt.ylim(24, 25)

#Adicionado os rótulos acima das barras para destacar os valores
for barra2 in barras2:
    altura2 = barra2.get_height()
    plt.text(
        barra2.get_x() + barra2.get_width() / 2, altura2 + 0.1, #Posição acima da barra
        f'{altura2:.2f}%', #Valor da barra com duas casas decimais
        ha='center', va='bottom', fontsize=16, color='black', fontweight='bold'
    )

#Ajustando os rótulos e o título
plt.title("Comparação da Porcentagem de Mulheres em Dados (2022 vs 2023)", fontsize=16, fontweight='bold')
plt.ylabel("Porcentagem (%)", fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Ajustar as margens
plt.subplots_adjust(top=0.9, bottom=0.15)

#Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
#Dados comparativos entre homens de 2022 e 2023
categorias3 = ["Homens em Dados em 2022", "Homens em Dados em 2023"]
valores3 = [quantidade_homens_2022, quantidade_homens_2023]

#Criando o gráfico de barras
plt.figure(figsize=(8, 6)) #Ajuste o tamanho da figura
barras3 = plt.bar(categorias3, valores3, color='blue', edgecolor = 'black')

#Ajustando o eixo Y
plt.ylim(3000, 4100)

#Adicionado os rótulos acima das barras
for barra3 in barras3:
    altura3 = barra3.get_height()
    plt.text(
        barra3.get_x() + barra3.get_width() / 2, altura3 + 10, #Posição acima da barra
        f'{altura3}', #Valor da barra
        ha='center', va='bottom',fontsize=12, color='black', fontweight='bold'
    )

#Ajustando os rótulos e os títulos
plt.title("Comparação do total de homens em dados (2022 vs 2023)", fontsize=14, fontweight='bold')
plt.ylabel("Quantidade", fontsize=12)
plt.xticks(fontsize = 11)
plt.yticks(fontsize = 11)

#Mostrando o gráfico
plt.tight_layout()
plt.show()

# %%
#Comparação percentual entre homens 2022 e 2023

categorias4 = ["Porcentagem de homens em dados em 2022", "Porcentagem de homem em dados 2023"]
valores4 =[porcentagem_homens_2022, porcentagem_homens_2023]

plt.figure(figsize=(12, 7)) #Ajusta o tamanho da figura
barras4 = plt.bar(categorias4, valores4, color='blue', edgecolor='black')
plt.ylim(74, 76)
for barra4 in barras4:
    altura4 = barra4.get_height()
    plt.text(
        barra4.get_x() + barra4.get_width() / 2, altura4 + 0.1,
        f'{altura4:.2f}%',
        ha='center', va='bottom', fontsize=10, color='black', fontweight='bold'
            )
    
plt.title("Comparação Percentual de Homens em Dados 2024", fontsize=16, fontweight='bold')
plt.ylabel("Porcentagem (%)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.subplots_adjust(top=0.9, bottom=0.15) #Ajustar as margens
plt.tight_layout()
plt.show()

# %%
# Configurando as cores
cores = ['blue', '#FF69B4']

#Comparação Absoluta
categorias_absolutas = ["Homens (2022)", "Homens (2023)", "Mulheres (2022)", "Mulheres (2023)"]
valores_absolutos = [
    quantidade_homens_2022, 
    quantidade_homens_2023, 
    quantidade_mulheres_2022, 
    quantidade_mulheres_2023
]

plt.figure(figsize=(10, 6))
barras5 = plt.bar(categorias_absolutas, valores_absolutos, color=[cores[0], cores[0], cores[1], cores[1]], edgecolor='black')

# Adicionando rótulos com os valores acima das barras
for barra5 in barras5:
    altura5 = barra5.get_height()
    plt.text(
        barra5.get_x() + barra5.get_width() / 2, altura5 + 20, 
        f'{altura5}', ha='center', va='bottom', fontsize=10, fontweight='bold'
    )

plt.ylim(1000, 4100)

# Ajustando rótulos e título
plt.title("Comparação Absoluta entre Homens e Mulheres (2022 vs 2023)", fontsize=14, fontweight='bold')
plt.ylabel("Quantidade", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

plt.tight_layout()
cores = ['blue', '#FF69B4']
plt.show()

# %%
#Comparação Percentual entre Homens e Mulheres 2022 e 2023
cores = ['blue', '#FF69B4']
categorias_percentuais = ["Homens (2022)", "Homens (2023)", "Mulheres (2022)", "Mulheres (2023)"]
valores_percentuais = [
    porcentagem_homens_2022, 
    porcentagem_homens_2023, 
    porcentagem_mulheres_2022, 
    porcentagem_mulheres_2023
]

plt.figure(figsize=(10, 6))
barras6 = plt.bar(categorias_percentuais, valores_percentuais, color=[cores[0], cores[0], cores[1], cores[1]], edgecolor='black')

# Adicionando rótulos com os valores acima das barras (com duas casas decimais)
for barra6 in barras6:
    altura6 = barra6.get_height()
    plt.text(
        barra6.get_x() + barra6.get_width() / 2, altura6 + 0.3, 
        f'{altura6:.2f}%', ha='center', va='bottom', fontsize=10, fontweight='bold'
    )

plt.ylim(20, 80)

# Ajustando os eixos e o título
plt.title("Comparação Percentual entre Homens e Mulheres (2022 vs 2023)", fontsize=14, fontweight='bold')
plt.ylabel("Porcentagem (%)", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

plt.tight_layout()
plt.show()
